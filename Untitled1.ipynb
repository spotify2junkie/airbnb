# %%
from graphviz import Digraph

dot = Digraph(comment='The Round Table')
dot.attr('node',color='dodgerblue', style='filled')
# dot.attr(color='blue', style='filled')
dot.node('A', 'Visualize Crime Counts')
dot.node('B','Filter "Safe" Community')
dot.node('C', 'Identify Airbnb We can Book')
# dot.node('B', 'Filter "Safe" Community')
# dot.node('C', 'Identify Airbnb We can Book')

# dot.edges(['AB', 'BC'])




dot.attr('node', shape='box',color='orange', style='filled')

dot.node('D',"Load crime data")
dot.node('E','calculate within\n neighborhood')
dot.node('F','Plot community,\nfilled by crime counts')
dot.node('G',"eyeball communities we \nwill stay through plot")
dot.node('H','slice dataframe for \neach chosen community')
dot.node('I','Calculate crime happened \nwithin 0.1km range \nof each airbnb list')
dot.node('J','select listings we can book')
dot.edges(['AD','AE',"AF","BG","BH","CI","CJ"])
dot
